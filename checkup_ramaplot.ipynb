# %%
from pyrama import calc_ramachandran
from pyrama import plot_ramachandran

# %%
normals, outliers = calc_ramachandran(["./input_example/model01.pdb"])
plot_ramachandran(normals, outliers)

# %%
normals, outliers = calc_ramachandran(["./input_example/model02.pdb"])
plot_ramachandran(normals, outliers)

# %%
normals, outliers = calc_ramachandran(["./input_example/model03.pdb"])
plot_ramachandran(normals, outliers)

# %%
normals, outliers = calc_ramachandran(["./input_example/model04.pdb"])
plot_ramachandran(normals, outliers)

# %%
normals, outliers = calc_ramachandran(["./input_example/model05.pdb"])
plot_ramachandran(normals, outliers)
